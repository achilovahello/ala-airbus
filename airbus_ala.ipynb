# %%
import pandas as pd
import numpy as np

# %%
ala=pd.read_csv('Airbus.csv')

# %%
ala.head()
# Out:
#    Nights  AIMSID                                               NAME  Fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base Position FlightDate  FlightNo FlightPostfix DepartureAirport   ARR  \
# 0  ALA       CP     00:00.0       875                           ALA   DME
# 1  ALA       CP     00:00.0       875                           ALA   DME
# 2  ALA       CP     00:00.0       267                           ALA   PEK
# 3  ALA       CP     00:00.0       875                           ALA   DME
# 4  ALA       CP     00:00.0       875                           ALA   DME
#
#    STD   STA    CrewType INTL_LAYOVER_TIME LAYOVER_TIME
# ...

# %%
ala.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 16 columns):
# Nights               305 non-null int64
# AIMSID               305 non-null int64
# NAME                 305 non-null object
# Fleet                305 non-null int64
# base                 305 non-null object
# Position             305 non-null object
# FlightDate           305 non-null object
# FlightNo             305 non-null int64
# FlightPostfix        305 non-null object
# DepartureAirport     305 non-null object
# ARR                  305 non-null object
# STD                  305 non-null int64
# STA                  305 non-null int64
# CrewType             305 non-null object
# INTL_LAYOVER_TIME    305 non-null object
# LAYOVER_TIME         305 non-null object
# dtypes: int64(6), object(10)
# memory usage: 38.2+ KB

# %%
ala.drop(['DepartureAirport', 'CrewType', 'INTL_LAYOVER_TIME'],axis=1, inplace=True)

# %%
ala.head()
# Out:
#    Nights  AIMSID                                               NAME  Fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base Position FlightDate  FlightNo FlightPostfix   ARR  STD   STA  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   LAYOVER_TIME
# 0        23:50
# 1        23:50
# 2        23:15
# 3        23:45
# ...

# %%
ala.rename(columns=lambda x:x.replace('_','').lower(), inplace=True)

# %%
ala.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
ala.aimsid.unique()
# Out:
# array([   41,    97,   547,   626,   661,   768,   774,   776,   835,
#          870,  1447,  2008,  2360,  2489,  2490,  2661,  3185,  3481,
#         3522,  3776,  4359,  4599,  5178,  5180,  5294,  5295,  5337,
#         5394,  5454,  5623,  5738,  5964,  6391,  6533,  6607,  7014,
#         7354,  7549,  7573,  7574,  8077,  8140,  8141,  8142,  8149,
#         9069,  9105,  9584,  9644,  9647, 10340, 10585, 96385, 96456,
#        96499, 96503, 96506, 96521, 96536,    76,   226,   229,   498,
#          781,   884,  1269,  2045,  2077,  4077,  4358,  4600,  6145,
#         6520,  6679,  6837,  7281,  7355,  8143,  9106, 10221, 95042,
#        96324, 96389, 96500, 96543, 96628, 96640, 96680])

# %%
ala[ala['aimsid']==41]
# Out:
#      nights  aimsid                                               name  fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 230       2      41  ZHILISBAYEV MARAT                             ...    320
# 231       2      41  ZHILISBAYEV MARAT                             ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0    ALA       CP     00:00.0       875                DME   775  1070
# 1    ALA       CP     00:00.0       875                DME   775  1070
# 230  ALA       CP     00:00.0       903                AMS   135   460
# 231  ALA       CP     00:00.0       153                LED   135   460
#
#     layovertime
# 0         23:50
# 1         23:50
# 230    49:20:00
# 231    57:35:00

# %%
ala.arr.unique()
# Out:
# array(['DME ', 'PEK ', 'IST ', 'FRA ', 'LED ', 'KBP ', 'AMS ', 'DXB '],
#       dtype=object)

# %%
dme=ala[ala['arr'].str.strip()=='DME']
dme
# Out:
#      nights  aimsid                                               name  fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 3         0     547  STULBO GENNADIY                               ...    320
# 4         0     626  BEKEYEV ZHANAIDAR                             ...    320
# 5         0     661  NEKRASSOV ANATOLIY                            ...    320
# 8         0     774  SADYKOV SAMAT                                 ...    320
# 9         0     776  KIRCHU BORIS                                  ...    320
# 10        0     835  DADISHEV LEONID                               ...    320
# 13        0     870  ABDUKARIMOV SERGEY                            ...    320
# 15        0    1447  KHEGAY VYACHESLAV                             ...    320
# 18        0    1447  KHEGAY VYACHESLAV                             ...    320
# ...

# %%
dme.arr.unique()
# Out:
# array(['DME '], dtype=object)

# %%
res_dme=dme.groupby('aimsid')['arr'].value_counts()

# %%
res_dme.head()
# Out:
# aimsid  arr
# 41      DME     2
# 547     DME     1
# 626     DME     1
# 661     DME     1
# 774     DME     1
# Name: arr, dtype: int64

# %%
DME_FULL=ala.merge(res_dme, on ='aimsid', how='left')

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  arr_y
# 0       23:50    2.0
# 1       23:50    2.0
# 2       23:15    NaN
# ...

# %%
DME_FULL=DME_FULL.rename(columns={"arr_y":"DME"})

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME
# 0       23:50  2.0
# 1       23:50  2.0
# 2       23:15  NaN
# ...

# %%
##заменить нан на 0 
##convert float na int
#delete duplicates

ala.head(5)
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
DME_FULL=DME_FULL.fillna(0)

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME
# 0       23:50  2.0
# 1       23:50  2.0
# 2       23:15  0.0
# ...

# %%
DME_FULL=DME_FULL.astype({"DME":"int32"})

# %%
PEK=ala[ala['arr'].str.strip()=='PEK']

# %%
PEK=PEK.groupby('aimsid')['arr'].value_counts()

# %%
PEK=PEK.fillna(0)

# %%
PEK.head()
# Out:
# aimsid  arr
# 76      PEK     1
# 97      PEK     1
# 626     PEK     1
# 768     PEK     2
# 835     PEK     1
# Name: arr, dtype: int64

# %%
DME_PEK=DME_FULL.merge(PEK, on ='aimsid', how='left')

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  arr
# 0       23:50    2  NaN
# 1       23:50    2  NaN
# ...

# %%
DME_PEK.count()
# Out:
# nights           305
# aimsid           305
# name             305
# fleet            305
# base             305
# position         305
# flightdate       305
# flightno         305
# flightpostfix    305
# arr_x            305
# std              305
# sta              305
# layovertime      305
# DME              305
# arr              132
# dtype: int64

# %%
DME_PEK=DME_PEK.fillna(0)

# %%
DME_PEK= DME_PEK.astype({"arr":"int32"})

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  arr
# 0       23:50    2    0
# 1       23:50    2    0
# ...

# %%
DME_PEK=DME_PEK.rename(columns={"arr":"PEK"})

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK
# 0       23:50    2    0
# 1       23:50    2    0
# ...

# %%
IST=ala[ala['arr'].str.strip()=='IST']

# %%
IST.head()
# Out:
#     nights  aimsid                                               name  fleet  \
# 6        0     661  NEKRASSOV ANATOLIY                            ...    320
# 39       0    5294  SHAIKEN MADIYAR                               ...    320
# 47       0    5738  BELYAYEV YEVGENIY                             ...    320
# 51       0    6533  SEBEKOV YERZHAN                               ...    320
# 64       0    7574  TURMATOV YERNUR                               ...    320
#
#     base position flightdate  flightno flightpostfix   arr  std   sta  \
# 6   ALA       CP     00:00.0       911                IST   715  1085
# 39  ALA       FO     00:00.0       911                IST   715  1085
# 47  ALA       CP     00:00.0       911                IST   715  1085
# 51  ALA       FO     00:00.0       911                IST   715  1085
# 64  ALA       FO     00:00.0       911                IST   715  1085
#
#    layovertime
# 6        23:25
# 39       22:55
# 47       22:30
# ...

# %%
IST=IST.groupby('aimsid')['arr'].value_counts()

# %%
IST.head()
# Out:
# aimsid  arr
# 229     IST     1
# 547     IST     1
# 661     IST     1
# 776     IST     1
# 781     IST     1
# Name: arr, dtype: int64

# %%
DME_PEK_IST=DME_PEK.merge(IST, on ='aimsid', how='left')

# %%
DME_PEK_IST=DME_PEK_IST.fillna(0)

# %%
DME_PEK_IST.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  arr
# 0       23:50    2    0  0.0
# 1       23:50    2    0  0.0
# ...

# %%
DME_PEK_IST=DME_PEK_IST.astype({"arr":"int32"})

# %%
DME_PEK_IST[DME_PEK_IST.duplicated()]
# Out:
#    nights  aimsid                                               name  fleet  \
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 1  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  arr
# 1       23:50    2    0    0

# %%
DME_PEK_IST=DME_PEK_IST.drop_duplicates()

# %%
DME_PEK_IST.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 5       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
# 5  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  arr
# 0       23:50    2    0    0
# 2       23:15    0    1    0
# ...

# %%
DME_PEK_IST=DME_PEK_IST.rename(columns={"arr":"IST"})

# %%
FRA=ala[ala['arr'].str.strip()=='FRA']

# %%
FRA.head()
# Out:
#      nights  aimsid                                               name  fleet  \
# 7         0     768  MUSTAFIN RAFKAT                               ...    320
# 55        0    7014  KUZBAKOV NURZHAN                              ...    320
# 91        0   96506  DIAPOULIS ALVERTOS                            ...    320
# 289       3    2490  AKHMETOV GABIT                                ...    320
# 290       3    2661  SHUKEVICH VLADISLAV                           ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std  sta  \
# 7    ALA       CP     00:00.0       937                FRA   430  710
# 55   ALA       FO     00:00.0       937                FRA   430  710
# 91   ALA       CP     00:00.0       937                FRA   430  710
# 289  ALA       CP     00:00.0       947                FRA    20  330
# 290  ALA       CP     00:00.0       947                FRA    20  330
#
#     layovertime
# 7         18:30
# 55        18:30
# 91        18:50
# ...

# %%
FRA=FRA.groupby('aimsid')['arr'].value_counts()

# %%
FRA.head()
# Out:
# aimsid  arr
# 768     FRA     1
# 2490    FRA     1
# 2661    FRA     1
# 3776    FRA     1
# 5180    FRA     1
# Name: arr, dtype: int64

# %%
DME_PEK_IST_FRA=DME_PEK_IST.merge(FRA, on ='aimsid', how='left')

# %%
DME_PEK_IST_FRA=DME_PEK_IST_FRA.fillna(0)

# %%
DME_PEK_IST_FRA=DME_PEK_IST_FRA.astype({"arr":"int32"})

# %%
DME_PEK_IST_FRA=DME_PEK_IST_FRA.rename(columns={"arr":"FRA"})

# %%
DME_PEK_IST_FRA.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       267                PEK   980  1255
# 2  ALA       CP     00:00.0       875                DME   775  1070
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  IST  FRA
# 0       23:50    2    0    0    0
# ...

# %%
ala.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
LED=ala[ala['arr'].str.strip()=='LED']

# %%
LED.head()
# Out:
#     nights  aimsid                                               name  fleet  \
# 12       0     835  DADISHEV LEONID                               ...    320
# 17       0    1447  KHEGAY VYACHESLAV                             ...    320
# 21       0    2360  SAGANDYKOV MARSEL                             ...    320
# 23       0    2490  AKHMETOV GABIT                                ...    320
# 27       0    3185  TUNLIKBAYEV DAUREN                            ...    320
#
#     base position flightdate  flightno flightpostfix   arr  std   sta  \
# 12  ALA       FO     00:00.0       135                LED   735  1060
# 17  ALA       CP     00:00.0       135                LED   735  1060
# 21  ALA       FO     00:00.0       135                LED   735  1060
# 23  ALA       CP     00:00.0       135                LED   735  1060
# 27  ALA       CP     00:00.0       135                LED   735  1060
#
#    layovertime
# 12       14:00
# 17       22:35
# 21       14:40
# ...

# %%
LED=LED.groupby('aimsid')['arr'].value_counts()

# %%
DME_PEK_IST_FRA_LED=DME_PEK_IST_FRA.merge(LED, on='aimsid', how='left')

# %%
DME_PEK_IST_FRA_LED.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       267                PEK   980  1255
# 2  ALA       CP     00:00.0       875                DME   775  1070
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  IST  FRA  arr
# 0       23:50    2    0    0    0  1.0
# ...

# %%
DME_PEK_IST_FRA_LED=DME_PEK_IST_FRA_LED.rename(columns={"arr":"LED"})

# %%
DME_PEK_IST_FRA_LED=DME_PEK_IST_FRA_LED.fillna(0)

# %%
DME_PEK_IST_FRA_LED=DME_PEK_IST_FRA_LED.astype({"LED":"int32"})

# %%
DME_PEK_IST_FRA_LED.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       267                PEK   980  1255
# 2  ALA       CP     00:00.0       875                DME   775  1070
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  IST  FRA  LED
# 0       23:50    2    0    0    0    1
# ...

# %%
KBP=ala[ala['arr'].str.strip()=='KBP']

# %%
KBP.head()
# Out:
#      nights  aimsid                                               name  fleet  \
# 95        1     226  TUPELEV MARAT                                 ...    320
# 105       1     776  KIRCHU BORIS                                  ...    320
# 106       1     776  KIRCHU BORIS                                  ...    320
# 112       1    1269  KALYMBETOV KAIRAT                             ...    320
# 115       1    2045  ORLOV SERGEY                                  ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std   sta  \
# 95   ALA       CP     00:00.0       401                KBP   710  1025
# 105  ALA       CP     00:00.0       401                KBP   710  1025
# 106  ALA       CP     00:00.0       401                KBP   710  1025
# 112  ALA       CP     00:00.0       401                KBP   725  1045
# 115  ALA       FO     00:00.0       401                KBP   725  1045
#
#     layovertime
# 95     37:10:00
# 105        47,5
# 106    47:30:00
# ...

# %%
KBP=KBP.groupby('aimsid')['arr'].value_counts()

# %%
KBP.head()
# Out:
# aimsid  arr
# 76      KBP     2
# 226     KBP     1
# 498     KBP     1
# 626     KBP     1
# 661     KBP     1
# Name: arr, dtype: int64

# %%
DME_PEK_IST_FRA_LED_KBP=DME_PEK_IST_FRA_LED.merge(KBP, on='aimsid', how='left')

# %%
DME_PEK_IST_FRA_LED_KBP=DME_PEK_IST_FRA_LED_KBP.rename(columns={"arr":"KBP"})

# %%
DME_PEK_IST_FRA_LED_KBP=DME_PEK_IST_FRA_LED_KBP.fillna(0)

# %%
DME_PEK_IST_FRA_LED_KBP=DME_PEK_IST_FRA_LED_KBP.astype({"KBP":"int32"})

# %%
DME_PEK_IST_FRA_LED_KBP.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       267                PEK   980  1255
# 2  ALA       CP     00:00.0       875                DME   775  1070
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  IST  FRA  LED  KBP
# 0       23:50    2    0    0    0    1    0
# ...

# %%
AMS=ala[ala['arr'].str.strip()=='AMS']

# %%
AMS.head()
# Out:
#      nights  aimsid                                               name  fleet  \
# 96        1     229  URAZAKOV ARTUR                                ...    320
# 109       1     870  ABDUKARIMOV SERGEY                            ...    320
# 114       1    2045  ORLOV SERGEY                                  ...    320
# 120       1    2360  SAGANDYKOV MARSEL                             ...    320
# 123       1    2490  AKHMETOV GABIT                                ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std  sta  \
# 96   ALA       CP     00:00.0       903                AMS   135  460
# 109  ALA       FO     00:00.0       903                AMS   135  460
# 114  ALA       FO     00:00.0       903                AMS   135  460
# 120  ALA       FO     00:00.0       903                AMS   135  460
# 123  ALA       CP     00:00.0       903                AMS   135  460
#
#     layovertime
# 96     25:25:00
# 109    25:10:00
# 114    25:50:00
# ...

# %%
AMS=AMS.groupby('aimsid')['arr'].value_counts()

# %%
AMS.head()
# Out:
# aimsid  arr
# 41      AMS     1
# 229     AMS     2
# 547     AMS     2
# 870     AMS     1
# 2045    AMS     1
# Name: arr, dtype: int64

# %%
DME_PEK_IST_FRA_LED_KBP_AMS=DME_PEK_IST_FRA_LED_KBP.merge(AMS, on='aimsid', how='left')

# %%
DME_PEK_IST_FRA_LED_KBP_AMS=DME_PEK_IST_FRA_LED_KBP_AMS.rename(columns={"arr":"AMS"})

# %%
DME_PEK_IST_FRA_LED_KBP_AMS=DME_PEK_IST_FRA_LED_KBP_AMS.fillna(0)

# %%
DME_PEK_IST_FRA_LED_KBP_AMS=DME_PEK_IST_FRA_LED_KBP_AMS.astype({"AMS":"int32"})

# %%
DME_PEK_IST_FRA_LED_KBP_AMS.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       267                PEK   980  1255
# 2  ALA       CP     00:00.0       875                DME   775  1070
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  IST  FRA  LED  KBP  AMS
# ...

# %%
ala[ala['aimsid']==547]
# Out:
#      nights  aimsid                                               name  fleet  \
# 3         0     547  STULBO GENNADIY                               ...    320
# 237       2     547  STULBO GENNADIY                               ...    320
# 238       2     547  STULBO GENNADIY                               ...    320
# 285       3     547  STULBO GENNADIY                               ...    320
# 286       3     547  STULBO GENNADIY                               ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std   sta  \
# 3    ALA       CP     00:00.0       875                DME   775  1070
# 237  ALA       CP     00:00.0       911                IST   715  1085
# 238  ALA       CP     00:00.0       153                LED   135   460
# 285  ALA       CP     00:00.0       903                AMS   135   460
# 286  ALA       CP     00:00.0       903                AMS   135   460
#
#     layovertime
# 3         23:45
# 237    48:10:00
# 238    57:25:00
# ...

# %%
DXB=ala[ala['arr'].str.strip()=='DXB']

# %%
DXB.head()
# Out:
#      nights  aimsid                                               name  fleet  \
# 155       1    6391  ALEKEYEV ELDAR                                ...    320
# 211       1   95042  LUKE LEWIS                                    ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std  sta  \
# 155  ALA       FO     00:00.0       895                DXB   100  385
# 211  ALA       CP     00:00.0       895                DXB   100  385
#
#     layovertime
# 155    31:35:00
# 211    31:35:00

# %%
DXB=DXB.groupby('aimsid')['arr'].value_counts()

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS.merge(DXB, on ='aimsid', how='left')

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS_DXB.rename(columns={"arr":"DXB"})

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS_DXB.fillna(0)

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS_DXB.astype({"DXB":"int32"})

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  ...   sta  \
# 0  ALA       CP     00:00.0       875                DME   ...  1070
# 1  ALA       CP     00:00.0       267                PEK   ...  1255
# 2  ALA       CP     00:00.0       875                DME   ...  1070
# 3  ALA       CP     00:00.0       875                DME   ...  1070
# 4  ALA       CP     00:00.0       875                DME   ...  1070
#
#    layovertime DME  PEK  IST  FRA  LED  KBP  AMS  DXB
# ...

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS_DXB.drop(columns=['flightdate', 'flightno', 'flightpostfix', 'arr_x'])

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB=DME_PEK_IST_FRA_LED_KBP_AMS_DXB.drop(columns=['std', 'sta', 'layovertime'])

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    base position  DME  PEK  IST  FRA  LED  KBP  AMS  DXB
# 0  ALA       CP     2    0    0    0    1    0    1    0
# 1  ALA       CP     0    1    0    0    0    0    0    0
# 2  ALA       CP     1    0    1    0    1    0    2    0
# 3  ALA       CP     1    1    0    0    1    1    0    0
# 4  ALA       CP     1    0    1    0    1    1    0    0

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB.count()
# Out:
# nights      304
# aimsid      304
# name        304
# fleet       304
# base        304
# position    304
# DME         304
# PEK         304
# IST         304
# FRA         304
# LED         304
# KBP         304
# AMS         304
# DXB         304
# dtype: int64

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB.rename(columns = lambda x:x.upper(), inplace = True)

# %%
DME_PEK_IST_FRA_LED_KBP_AMS_DXB.head()
# Out:
#    NIGHTS  AIMSID                                               NAME  FLEET  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      97  SATBALDIYEV ADIL                              ...    320
# 2       0     547  STULBO GENNADIY                               ...    320
# 3       0     626  BEKEYEV ZHANAIDAR                             ...    320
# 4       0     661  NEKRASSOV ANATOLIY                            ...    320
#
#    BASE POSITION  DME  PEK  IST  FRA  LED  KBP  AMS  DXB
# 0  ALA       CP     2    0    0    0    1    0    1    0
# 1  ALA       CP     0    1    0    0    0    0    0    0
# 2  ALA       CP     1    0    1    0    1    0    2    0
# 3  ALA       CP     1    1    0    0    1    1    0    0
# 4  ALA       CP     1    0    1    0    1    1    0    0
