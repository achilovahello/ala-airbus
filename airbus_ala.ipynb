# %%
import pandas as pd
import numpy as np

# %%
ala=pd.read_csv('Airbus.csv')

# %%
ala
# Out:
#      Nights  AIMSID                                               NAME  Fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 2         0      97  SATBALDIYEV ADIL                              ...    320
# 3         0     547  STULBO GENNADIY                               ...    320
# 4         0     626  BEKEYEV ZHANAIDAR                             ...    320
# 5         0     661  NEKRASSOV ANATOLIY                            ...    320
# 6         0     661  NEKRASSOV ANATOLIY                            ...    320
# 7         0     768  MUSTAFIN RAFKAT                               ...    320
# 8         0     774  SADYKOV SAMAT                                 ...    320
# 9         0     776  KIRCHU BORIS                                  ...    320
# 10        0     835  DADISHEV LEONID                               ...    320
# 11        0     835  DADISHEV LEONID                               ...    320
# 12        0     835  DADISHEV LEONID                               ...    320
# 13        0     870  ABDUKARIMOV SERGEY                            ...    320
# 14        0     870  ABDUKARIMOV SERGEY                            ...    320
# 15        0    1447  KHEGAY VYACHESLAV                             ...    320
# 16        0    1447  KHEGAY VYACHESLAV                             ...    320
# 17        0    1447  KHEGAY VYACHESLAV                             ...    320
# 18        0    1447  KHEGAY VYACHESLAV                             ...    320
# 19        0    2008  ARTEMENKO MIKHAIL                             ...    320
# 20        0    2008  ARTEMENKO MIKHAIL                             ...    320
# 21        0    2360  SAGANDYKOV MARSEL                             ...    320
# 22        0    2489  BAIKHOJAYEV AMANGELDY                         ...    320
# 23        0    2490  AKHMETOV GABIT                                ...    320
# 24        0    2490  AKHMETOV GABIT                                ...    320
# 25        0    2661  SHUKEVICH VLADISLAV                           ...    320
# 26        0    2661  SHUKEVICH VLADISLAV                           ...    320
# 27        0    3185  TUNLIKBAYEV DAUREN                            ...    320
# 28        0    3185  TUNLIKBAYEV DAUREN                            ...    320
# 29        0    3481  TSOY PAVEL                                    ...    320
# ..      ...     ...                                                ...    ...
# 275       2   10340  SKRIBACHEV VADIM                              ...    320
# 276       2   96385  TOPP HANSGEORG                                ...    320
# 277       2   96385  TOPP HANSGEORG                                ...    320
# 278       2   96521  NIKOLOV GEORGI                                ...    320
# 279       2   96521  NIKOLOV GEORGI                                ...    320
# 280       2   96521  NIKOLOV GEORGI                                ...    320
# 281       2   96536  PETROV NIKOLAY                                ...    320
# 282       2   96536  PETROV NIKOLAY                                ...    320
# 283       2   96543  STOJANOVIC NENAD                              ...    320
# 284       3     229  URAZAKOV ARTUR                                ...    320
# 285       3     547  STULBO GENNADIY                               ...    320
# 286       3     547  STULBO GENNADIY                               ...    320
# 287       3     626  BEKEYEV ZHANAIDAR                             ...    320
# 288       3    2360  SAGANDYKOV MARSEL                             ...    320
# 289       3    2490  AKHMETOV GABIT                                ...    320
# 290       3    2661  SHUKEVICH VLADISLAV                           ...    320
# 291       3    3776  YELEUOV YERMEK                                ...    320
# 292       3    4077  TURYSBEKOV ARMAN                              ...    320
# 293       3    5180  RESHETNIKOV ALEXANDR                          ...    320
# 294       3    5394  ISSAYEV SAYAN                                 ...    320
# 295       3    5623  BEKEYEV ASHIR                                 ...    320
# 296       3    6520  LAPOCHKIN ALEXANDR                            ...    320
# 297       3    6533  SEBEKOV YERZHAN                               ...    320
# 298       3    6837  SAKENOV ILYAS                                 ...    320
# 299       3    6837  SAKENOV ILYAS                                 ...    320
# 300       3    7549  BYZHIBEKOV TALGAT                             ...    320
# 301       3    8141  DUDINOV VALERIY                               ...    320
# 302       3    9069  ZHARKOV ROMAN                                 ...    320
# 303       3   96385  TOPP HANSGEORG                                ...    320
# 304       3   96640  PANIC IGOR                                    ...    320
#
#      base Position FlightDate  FlightNo FlightPostfix DepartureAirport   ARR  \
# 0    ALA       CP     00:00.0       875                           ALA   DME
# 1    ALA       CP     00:00.0       875                           ALA   DME
# 2    ALA       CP     00:00.0       267                           ALA   PEK
# 3    ALA       CP     00:00.0       875                           ALA   DME
# 4    ALA       CP     00:00.0       875                           ALA   DME
# 5    ALA       CP     00:00.0       875                           ALA   DME
# 6    ALA       CP     00:00.0       911                           ALA   IST
# 7    ALA       CP     00:00.0       937                           URA   FRA
# 8    ALA       CP     00:00.0       875                           ALA   DME
# 9    ALA       CP     00:00.0       875                           ALA   DME
# 10   ALA       FO     00:00.0       875                           ALA   DME
# 11   ALA       FO     00:00.0       267                           ALA   PEK
# 12   ALA       FO     00:00.0       135                           ALA   LED
# 13   ALA       FO     00:00.0       875                           ALA   DME
# 14   ALA       FO     00:00.0       267                           ALA   PEK
# 15   ALA       CP     00:00.0       875                           ALA   DME
# 16   ALA       CP     00:00.0       267                           ALA   PEK
# 17   ALA       CP     00:00.0       135                           ALA   LED
# 18   ALA       CP     00:00.0       875                           ALA   DME
# 19   ALA       CP     00:00.0       267                           ALA   PEK
# 20   ALA       CP     00:00.0       875                           ALA   DME
# 21   ALA       FO     00:00.0       135                           ALA   LED
# 22   ALA       FO     00:00.0       875                           ALA   DME
# 23   ALA       CP     00:00.0       135                           ALA   LED
# 24   ALA       CP     00:00.0       875                           ALA   DME
# 25   ALA       CP     00:00.0       267                           ALA   PEK
# 26   ALA       CP     00:00.0       267                           ALA   PEK
# 27   ALA       CP     00:00.0       135                           ALA   LED
# 28   ALA       CP     00:00.0       135                           ALA   LED
# 29   ALA       FO     00:00.0       875                           ALA   DME
# ..    ...      ...        ...       ...           ...              ...   ...
# 275  ALA       FO     00:00.0       911                           ALA   IST
# 276  ALA       FO     00:00.0       911                           ALA   IST
# 277  ALA       FO     00:00.0       401                           ALA   KBP
# 278  ALA       CP     00:00.0       135                           ALA   LED
# 279  ALA       CP     00:00.0       401                           ALA   KBP
# 280  ALA       CP     00:00.0       405                           ALA   KBP
# 281  ALA       CP     00:00.0       903                           GUW   AMS
# 282  ALA       CP     00:00.0       153                           ALA   LED
# 283  ALA       CP     00:00.0       903                           GUW   AMS
# 284  ALA       CP     00:00.0       903                           GUW   AMS
# 285  ALA       CP     00:00.0       903                           GUW   AMS
# 286  ALA       CP     00:00.0       903                           GUW   AMS
# 287  ALA       CP     00:00.0       405                           ALA   KBP
# 288  ALA       FO     00:00.0       903                           GUW   AMS
# 289  ALA       CP     00:00.0       947                           GUW   FRA
# 290  ALA       CP     00:00.0       947                           GUW   FRA
# 291  ALA       FO     00:00.0       947                           GUW   FRA
# 292  ALA       CP     00:00.0       903                           GUW   AMS
# 293  ALA       CP     00:00.0       947                           GUW   FRA
# 294  ALA       FO     00:00.0       947                           GUW   FRA
# 295  ALA       CP     00:00.0       947                           GUW   FRA
# 296  ALA       FO     00:00.0       947                           GUW   FRA
# 297  ALA       FO     00:00.0       903                           GUW   AMS
# 298  ALA       FO     00:00.0       947                           GUW   FRA
# 299  ALA       FO     00:00.0       947                           GUW   FRA
# 300  ALA       FO     00:00.0       947                           GUW   FRA
# 301  ALA       FO     00:00.0       903                           GUW   AMS
# 302  ALA       FO     00:00.0       903                           GUW   AMS
# 303  ALA       FO     00:00.0       405                           ALA   KBP
# 304  ALA       CP     00:00.0       903                           GUW   AMS
#
#      STD   STA    CrewType INTL_LAYOVER_TIME LAYOVER_TIME
# 0    775  1070  FlightDeck             23:50        23:50
# 1    775  1070  FlightDeck             23:50        23:50
# 2    980  1255  FlightDeck             23:15        23:15
# 3    775  1070  FlightDeck             23:45        23:45
# 4    775  1070  FlightDeck             23:20        23:20
# 5    775  1070  FlightDeck             23:45        23:45
# 6    715  1085  FlightDeck             23:25        23:25
# 7    430   710  FlightDeck             18:30        18:30
# 8    775  1070  FlightDeck             23:29        23:29
# 9    775  1070  FlightDeck             23:30        23:30
# 10   775  1070  FlightDeck             23:50        23:50
# 11   980  1255  FlightDeck             23:10        23:10
# 12   735  1060  FlightDeck             14:00        14:00
# 13   775  1070  FlightDeck             23:50        23:50
# 14   980  1255  FlightDeck             23:15        23:15
# 15   775  1070  FlightDeck             23:50        23:50
# 16   980  1255  FlightDeck             23:15        23:15
# 17   735  1060  FlightDeck             22:35        22:35
# 18   775  1070  FlightDeck             23:25        23:25
# 19   980  1255  FlightDeck             22:25        22:25
# 20   775  1070  FlightDeck             23:25        23:25
# 21   735  1060  FlightDeck             14:40        14:40
# 22   775  1070  FlightDeck             23:25        23:25
# 23   735  1060  FlightDeck             14:40        14:40
# 24   775  1070  FlightDeck             23:30        23:30
# 25   980  1255  FlightDeck             23,82        23,82
# 26   980  1255  FlightDeck             23:50        23:50
# 27   735  1060  FlightDeck             23,47        23,47
# 28   735  1060  FlightDeck             23:25        23:25
# 29   775  1070  FlightDeck             23:45        23:45
# ..   ...   ...         ...               ...          ...
# 275  715  1085  FlightDeck          48:55:00     48:55:00
# 276  715  1085  FlightDeck          48:10:00     48:10:00
# 277  710  1025  FlightDeck          48:45:00     48:45:00
# 278  735  1060  FlightDeck          48:10:00     48:10:00
# 279  710  1025  FlightDeck          48:45:00     48:45:00
# 280   55   390  FlightDeck          58:35:00     58:35:00
# 281  135   460  FlightDeck          49:35:00     49:35:00
# 282  135   460  FlightDeck          56:35:00     56:35:00
# 283  135   460  FlightDeck          49:30:00     49:30:00
# 284  135   460  FlightDeck          73:30:00     73:30:00
# 285  135   460  FlightDeck             73,07        73,07
# 286  135   460  FlightDeck          73:05:00     73:05:00
# 287   55   390  FlightDeck          83:00:00     83:00:00
# 288  135   460  FlightDeck          72:43:00     72:43:00
# 289   20   330  FlightDeck          78:15:00     78:15:00
# 290   20   330  FlightDeck          78:05:00     78:05:00
# 291   20   330  FlightDeck          78:15:00     78:15:00
# 292  135   460  FlightDeck          73:15:00     73:15:00
# 293   20   330  FlightDeck          78:15:00     78:15:00
# 294   20   330  FlightDeck          78:05:00     78:05:00
# 295   20   330  FlightDeck          78:05:00     78:05:00
# 296   20   330  FlightDeck          78:05:00     78:05:00
# 297  135   460  FlightDeck          73:30:00     73:30:00
# 298   20   330  FlightDeck             78,18        78,18
# 299   20   330  FlightDeck          78:10:00     78:10:00
# 300   20   330  FlightDeck          78:15:00     78:15:00
# 301  135   460  FlightDeck          73:15:00     73:15:00
# 302  135   460  FlightDeck          73:05:00     73:05:00
# 303   55   390  FlightDeck          83:00:00     83:00:00
# 304  135   460  FlightDeck          73:05:00     73:05:00
#
# [305 rows x 16 columns]

# %%
ala.head()
# Out:
#    Nights  AIMSID                                               NAME  Fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base Position FlightDate  FlightNo FlightPostfix DepartureAirport   ARR  \
# 0  ALA       CP     00:00.0       875                           ALA   DME
# 1  ALA       CP     00:00.0       875                           ALA   DME
# 2  ALA       CP     00:00.0       267                           ALA   PEK
# 3  ALA       CP     00:00.0       875                           ALA   DME
# 4  ALA       CP     00:00.0       875                           ALA   DME
#
#    STD   STA    CrewType INTL_LAYOVER_TIME LAYOVER_TIME
# 0  775  1070  FlightDeck             23:50        23:50
# 1  775  1070  FlightDeck             23:50        23:50
# 2  980  1255  FlightDeck             23:15        23:15
# 3  775  1070  FlightDeck             23:45        23:45
# 4  775  1070  FlightDeck             23:20        23:20

# %%
ala.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 16 columns):
# Nights               305 non-null int64
# AIMSID               305 non-null int64
# NAME                 305 non-null object
# Fleet                305 non-null int64
# base                 305 non-null object
# Position             305 non-null object
# FlightDate           305 non-null object
# FlightNo             305 non-null int64
# FlightPostfix        305 non-null object
# DepartureAirport     305 non-null object
# ARR                  305 non-null object
# STD                  305 non-null int64
# STA                  305 non-null int64
# CrewType             305 non-null object
# INTL_LAYOVER_TIME    305 non-null object
# LAYOVER_TIME         305 non-null object
# dtypes: int64(6), object(10)
# memory usage: 38.2+ KB

# %%
ala.drop(['DepartureAirport', 'CrewType', 'INTL_LAYOVER_TIME'],axis=1, inplace=True)

# %%
ala.head()
# Out:
#    Nights  AIMSID                                               NAME  Fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base Position FlightDate  FlightNo FlightPostfix   ARR  STD   STA  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   LAYOVER_TIME
# 0        23:50
# 1        23:50
# 2        23:15
# 3        23:45
# 4        23:20

# %%
ala.rename(columns=lambda x:x.replace('_','').lower(), inplace=True)

# %%
ala.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
ala.aimsid.unique()
# Out:
# array([   41,    97,   547,   626,   661,   768,   774,   776,   835,
#          870,  1447,  2008,  2360,  2489,  2490,  2661,  3185,  3481,
#         3522,  3776,  4359,  4599,  5178,  5180,  5294,  5295,  5337,
#         5394,  5454,  5623,  5738,  5964,  6391,  6533,  6607,  7014,
#         7354,  7549,  7573,  7574,  8077,  8140,  8141,  8142,  8149,
#         9069,  9105,  9584,  9644,  9647, 10340, 10585, 96385, 96456,
#        96499, 96503, 96506, 96521, 96536,    76,   226,   229,   498,
#          781,   884,  1269,  2045,  2077,  4077,  4358,  4600,  6145,
#         6520,  6679,  6837,  7281,  7355,  8143,  9106, 10221, 95042,
#        96324, 96389, 96500, 96543, 96628, 96640, 96680])

# %%
ala[ala['aimsid']==41]
# Out:
#      nights  aimsid                                               name  fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 230       2      41  ZHILISBAYEV MARAT                             ...    320
# 231       2      41  ZHILISBAYEV MARAT                             ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0    ALA       CP     00:00.0       875                DME   775  1070
# 1    ALA       CP     00:00.0       875                DME   775  1070
# 230  ALA       CP     00:00.0       903                AMS   135   460
# 231  ALA       CP     00:00.0       153                LED   135   460
#
#     layovertime
# 0         23:50
# 1         23:50
# 230    49:20:00
# 231    57:35:00

# %%
ala.arr.unique()
# Out:
# array(['DME ', 'PEK ', 'IST ', 'FRA ', 'LED ', 'KBP ', 'AMS ', 'DXB '],
#       dtype=object)

# %%
ala.groupby('aimsid')['arr'].value_counts()
# Out:
# aimsid  arr
# 41      DME     2
#         AMS     1
#         LED     1
# 76      KBP     2
#         PEK     1
# 97      PEK     1
# 226     KBP     1
#         LED     1
# 229     AMS     2
#         IST     1
#         LED     1
# 498     KBP     1
#         LED     1
# 547     AMS     2
#         DME     1
#         IST     1
#         LED     1
# 626     DME     1
#         KBP     1
#         LED     1
#         PEK     1
# 661     DME     1
#         IST     1
#         KBP     1
#         LED     1
# 768     PEK     2
#         FRA     1
#         LED     1
# 774     DME     1
# 776     KBP     3
#                ..
# 96324   IST     2
# 96385   DME     2
#         KBP     2
#         IST     1
#         PEK     1
# 96389   PEK     1
# 96456   IST     1
# 96499   IST     2
# 96500   IST     1
# 96503   DME     1
#         LED     1
#         PEK     1
# 96506   IST     2
#         FRA     1
#         KBP     1
# 96521   KBP     2
#         DME     1
#         LED     1
#         PEK     1
# 96536   AMS     1
#         DME     1
#         IST     1
#         KBP     1
#         LED     1
# 96543   AMS     1
#         IST     1
# 96628   IST     1
# 96640   AMS     2
# 96680   AMS     1
#         PEK     1
# Name: arr, Length: 248, dtype: int64

# %%
ala.arr.str.strip()
# Out:
# 0      DME
# 1      DME
# 2      PEK
# 3      DME
# 4      DME
# 5      DME
# 6      IST
# 7      FRA
# 8      DME
# 9      DME
# 10     DME
# 11     PEK
# 12     LED
# 13     DME
# 14     PEK
# 15     DME
# 16     PEK
# 17     LED
# 18     DME
# 19     PEK
# 20     DME
# 21     LED
# 22     DME
# 23     LED
# 24     DME
# 25     PEK
# 26     PEK
# 27     LED
# 28     LED
# 29     DME
#       ...
# 275    IST
# 276    IST
# 277    KBP
# 278    LED
# 279    KBP
# 280    KBP
# 281    AMS
# 282    LED
# 283    AMS
# 284    AMS
# 285    AMS
# 286    AMS
# 287    KBP
# 288    AMS
# 289    FRA
# 290    FRA
# 291    FRA
# 292    AMS
# 293    FRA
# 294    FRA
# 295    FRA
# 296    FRA
# 297    AMS
# 298    FRA
# 299    FRA
# 300    FRA
# 301    AMS
# 302    AMS
# 303    KBP
# 304    AMS
# Name: arr, Length: 305, dtype: object

# %%
ala.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
ala.arr.unique()
# Out:
# array(['DME ', 'PEK ', 'IST ', 'FRA ', 'LED ', 'KBP ', 'AMS ', 'DXB '],
#       dtype=object)

# %%
dme=ala[ala['arr'].str.strip()=='DME']
dme
# Out:
#      nights  aimsid                                               name  fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 3         0     547  STULBO GENNADIY                               ...    320
# 4         0     626  BEKEYEV ZHANAIDAR                             ...    320
# 5         0     661  NEKRASSOV ANATOLIY                            ...    320
# 8         0     774  SADYKOV SAMAT                                 ...    320
# 9         0     776  KIRCHU BORIS                                  ...    320
# 10        0     835  DADISHEV LEONID                               ...    320
# 13        0     870  ABDUKARIMOV SERGEY                            ...    320
# 15        0    1447  KHEGAY VYACHESLAV                             ...    320
# 18        0    1447  KHEGAY VYACHESLAV                             ...    320
# 20        0    2008  ARTEMENKO MIKHAIL                             ...    320
# 22        0    2489  BAIKHOJAYEV AMANGELDY                         ...    320
# 24        0    2490  AKHMETOV GABIT                                ...    320
# 29        0    3481  TSOY PAVEL                                    ...    320
# 30        0    3522  YESSIN ALEXANDR                               ...    320
# 31        0    3776  YELEUOV YERMEK                                ...    320
# 32        0    3776  YELEUOV YERMEK                                ...    320
# 33        0    4359  TAYUSHEV ALEXEY                               ...    320
# 34        0    4599  ZHAKENOV AIDAR                                ...    320
# 36        0    5178  PAVLOVA POLINA                                ...    320
# 37        0    5180  RESHETNIKOV ALEXANDR                          ...    320
# 38        0    5294  SHAIKEN MADIYAR                               ...    320
# 41        0    5295  TATARENKO LEONID                              ...    320
# 43        0    5394  ISSAYEV SAYAN                                 ...    320
# 48        0    5738  BELYAYEV YEVGENIY                             ...    320
# 49        0    5964  BEKEYEV AMANGELDY                             ...    320
# 50        0    6391  ALEKEYEV ELDAR                                ...    320
# 52        0    6607  ISSAK DANIYAR                                 ...    320
# 57        0    7354  IBRAYEV YERZHAN                               ...    320
# 59        0    7573  KOZHALIYEV YELNAR                             ...    320
# 60        0    7573  KOZHALIYEV YELNAR                             ...    320
# 61        0    7573  KOZHALIYEV YELNAR                             ...    320
# 62        0    7573  KOZHALIYEV YELNAR                             ...    320
# 63        0    7574  TURMATOV YERNUR                               ...    320
# 66        0    8077  ABILBEKOV DIAS                                ...    320
# 67        0    8140  KOTOROV PETR                                  ...    320
# 71        0    8141  DUDINOV VALERIY                               ...    320
# 76        0    9584  ALZHANOV MADI                                 ...    320
# 77        0    9644  GALIYEV FUAT                                  ...    320
# 79        0    9644  GALIYEV FUAT                                  ...    320
# 83        0   10585  SHAPAREV VLADISLAV                            ...    320
# 84        0   10585  SHAPAREV VLADISLAV                            ...    320
# 85        0   96385  TOPP HANSGEORG                                ...    320
# 86        0   96385  TOPP HANSGEORG                                ...    320
# 89        0   96503  IVANOV IVAN                                   ...    320
# 93        0   96536  PETROV NIKOLAY                                ...    320
# 110       1     884  USTINOV VLADIMIR                              ...    320
# 144       1    5295  TATARENKO LEONID                              ...    320
# 147       1    5337  OLKHOVSKIY STANISLAV                          ...    320
# 171       1    7355  TOKTAROV YERNAR                               ...    320
# 175       1    7549  BYZHIBEKOV TALGAT                             ...    320
# 222       1   96521  NIKOLOV GEORGI                                ...    320
#
#      base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0    ALA       CP     00:00.0       875                DME   775  1070
# 1    ALA       CP     00:00.0       875                DME   775  1070
# 3    ALA       CP     00:00.0       875                DME   775  1070
# 4    ALA       CP     00:00.0       875                DME   775  1070
# 5    ALA       CP     00:00.0       875                DME   775  1070
# 8    ALA       CP     00:00.0       875                DME   775  1070
# 9    ALA       CP     00:00.0       875                DME   775  1070
# 10   ALA       FO     00:00.0       875                DME   775  1070
# 13   ALA       FO     00:00.0       875                DME   775  1070
# 15   ALA       CP     00:00.0       875                DME   775  1070
# 18   ALA       CP     00:00.0       875                DME   775  1070
# 20   ALA       CP     00:00.0       875                DME   775  1070
# 22   ALA       FO     00:00.0       875                DME   775  1070
# 24   ALA       CP     00:00.0       875                DME   775  1070
# 29   ALA       FO     00:00.0       875                DME   775  1070
# 30   ALA       CP     00:00.0       875                DME   775  1070
# 31   ALA       FO     00:00.0       875                DME   775  1070
# 32   ALA       FO     00:00.0       875                DME   775  1070
# 33   ALA       CP     00:00.0       875                DME   775  1070
# 34   ALA       CP     00:00.0       875                DME   775  1070
# 36   ALA       FO     00:00.0       875                DME   775  1070
# 37   ALA       CP     00:00.0       875                DME   775  1070
# 38   ALA       FO     00:00.0       875                DME   775  1070
# 41   ALA       CP     00:00.0       875                DME   775  1070
# 43   ALA       FO     00:00.0       875                DME   775  1070
# 48   ALA       CP     00:00.0       875                DME   775  1070
# 49   ALA       CP     00:00.0       875                DME   775  1070
# 50   ALA       FO     00:00.0       875                DME   775  1070
# 52   ALA       FO     00:00.0       875                DME   775  1070
# 57   ALA       FO     00:00.0       875                DME   775  1070
# 59   ALA       FO     00:00.0       875                DME   775  1070
# 60   ALA       FO     00:00.0       875                DME   775  1070
# 61   ALA       FO     00:00.0       875                DME   775  1070
# 62   ALA       FO     00:00.0       875                DME   775  1070
# 63   ALA       FO     00:00.0       875                DME   775  1070
# 66   ALA       FO     00:00.0       875                DME   775  1070
# 67   ALA       FO     00:00.0       875                DME   775  1070
# 71   ALA       FO     00:00.0       875                DME   775  1070
# 76   ALA       FO     00:00.0       875                DME   775  1070
# 77   ALA       FO     00:00.0       875                DME   775  1070
# 79   ALA       FO     00:00.0       875                DME   775  1070
# 83   ALA       FO     00:00.0       875                DME   775  1070
# 84   ALA       FO     00:00.0       875                DME   775  1070
# 85   ALA       FO     00:00.0       875                DME   775  1070
# 86   ALA       FO     00:00.0       875                DME   775  1070
# 89   ALA       CP     00:00.0       875                DME   775  1070
# 93   ALA       CP     00:00.0       875                DME   775  1070
# 110  ALA       CP     00:00.0       875                DME   775  1070
# 144  ALA       CP     00:00.0       875                DME   775  1070
# 147  ALA       FO     00:00.0       875                DME   775  1070
# 171  ALA       FO     00:00.0       875                DME   775  1070
# 175  ALA       FO     00:00.0       875                DME   775  1070
# 222  ALA       CP     00:00.0       875                DME   775  1070
#
#     layovertime
# 0         23:50
# 1         23:50
# 3         23:45
# 4         23:20
# 5         23:45
# 8         23:29
# 9         23:30
# 10        23:50
# 13        23:50
# 15        23:50
# 18        23:25
# 20        23:25
# 22        23:25
# 24        23:30
# 29        23:45
# 30        23:05
# 31        23:50
# 32        22:51
# 33        23:20
# 34        22:51
# 36        23:25
# 37        23:45
# 38        23:30
# 41        23:10
# 43        23:40
# 48        23:25
# 49        23:20
# 50        23:30
# 52        23:20
# 57        23:30
# 59        20:30
# 60        23,67
# 61        23,73
# 62        23:40
# 63        23:29
# 66        23:25
# 67        23:50
# 71        23:55
# 76        23:50
# 77        23:45
# 79        23:10
# 83        23,35
# 84        23:22
# 85        23:05
# 86        23:20
# 89        23:40
# 93        20:30
# 110    26:25:00
# 144    24:00:00
# 147    24:00:00
# 171    26:25:00
# 175    24:00:00
# 222    24:00:00

# %%
dme.arr.unique()
# Out:
# array(['DME '], dtype=object)

# %%
res_dme=dme.groupby('aimsid')['arr'].value_counts()

# %%
res_dme.head()
# Out:
# aimsid  arr
# 41      DME     2
# 547     DME     1
# 626     DME     1
# 661     DME     1
# 774     DME     1
# Name: arr, dtype: int64

# %%
ala.merge(res_dme, on ='aimsid', how='left')
# Out:
#      nights  aimsid                                               name  fleet  \
# 0         0      41  ZHILISBAYEV MARAT                             ...    320
# 1         0      41  ZHILISBAYEV MARAT                             ...    320
# 2         0      97  SATBALDIYEV ADIL                              ...    320
# 3         0     547  STULBO GENNADIY                               ...    320
# 4         0     626  BEKEYEV ZHANAIDAR                             ...    320
# 5         0     661  NEKRASSOV ANATOLIY                            ...    320
# 6         0     661  NEKRASSOV ANATOLIY                            ...    320
# 7         0     768  MUSTAFIN RAFKAT                               ...    320
# 8         0     774  SADYKOV SAMAT                                 ...    320
# 9         0     776  KIRCHU BORIS                                  ...    320
# 10        0     835  DADISHEV LEONID                               ...    320
# 11        0     835  DADISHEV LEONID                               ...    320
# 12        0     835  DADISHEV LEONID                               ...    320
# 13        0     870  ABDUKARIMOV SERGEY                            ...    320
# 14        0     870  ABDUKARIMOV SERGEY                            ...    320
# 15        0    1447  KHEGAY VYACHESLAV                             ...    320
# 16        0    1447  KHEGAY VYACHESLAV                             ...    320
# 17        0    1447  KHEGAY VYACHESLAV                             ...    320
# 18        0    1447  KHEGAY VYACHESLAV                             ...    320
# 19        0    2008  ARTEMENKO MIKHAIL                             ...    320
# 20        0    2008  ARTEMENKO MIKHAIL                             ...    320
# 21        0    2360  SAGANDYKOV MARSEL                             ...    320
# 22        0    2489  BAIKHOJAYEV AMANGELDY                         ...    320
# 23        0    2490  AKHMETOV GABIT                                ...    320
# 24        0    2490  AKHMETOV GABIT                                ...    320
# 25        0    2661  SHUKEVICH VLADISLAV                           ...    320
# 26        0    2661  SHUKEVICH VLADISLAV                           ...    320
# 27        0    3185  TUNLIKBAYEV DAUREN                            ...    320
# 28        0    3185  TUNLIKBAYEV DAUREN                            ...    320
# 29        0    3481  TSOY PAVEL                                    ...    320
# ..      ...     ...                                                ...    ...
# 275       2   10340  SKRIBACHEV VADIM                              ...    320
# 276       2   96385  TOPP HANSGEORG                                ...    320
# 277       2   96385  TOPP HANSGEORG                                ...    320
# 278       2   96521  NIKOLOV GEORGI                                ...    320
# 279       2   96521  NIKOLOV GEORGI                                ...    320
# 280       2   96521  NIKOLOV GEORGI                                ...    320
# 281       2   96536  PETROV NIKOLAY                                ...    320
# 282       2   96536  PETROV NIKOLAY                                ...    320
# 283       2   96543  STOJANOVIC NENAD                              ...    320
# 284       3     229  URAZAKOV ARTUR                                ...    320
# 285       3     547  STULBO GENNADIY                               ...    320
# 286       3     547  STULBO GENNADIY                               ...    320
# 287       3     626  BEKEYEV ZHANAIDAR                             ...    320
# 288       3    2360  SAGANDYKOV MARSEL                             ...    320
# 289       3    2490  AKHMETOV GABIT                                ...    320
# 290       3    2661  SHUKEVICH VLADISLAV                           ...    320
# 291       3    3776  YELEUOV YERMEK                                ...    320
# 292       3    4077  TURYSBEKOV ARMAN                              ...    320
# 293       3    5180  RESHETNIKOV ALEXANDR                          ...    320
# 294       3    5394  ISSAYEV SAYAN                                 ...    320
# 295       3    5623  BEKEYEV ASHIR                                 ...    320
# 296       3    6520  LAPOCHKIN ALEXANDR                            ...    320
# 297       3    6533  SEBEKOV YERZHAN                               ...    320
# 298       3    6837  SAKENOV ILYAS                                 ...    320
# 299       3    6837  SAKENOV ILYAS                                 ...    320
# 300       3    7549  BYZHIBEKOV TALGAT                             ...    320
# 301       3    8141  DUDINOV VALERIY                               ...    320
# 302       3    9069  ZHARKOV ROMAN                                 ...    320
# 303       3   96385  TOPP HANSGEORG                                ...    320
# 304       3   96640  PANIC IGOR                                    ...    320
#
#      base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0    ALA       CP     00:00.0       875                DME   775  1070
# 1    ALA       CP     00:00.0       875                DME   775  1070
# 2    ALA       CP     00:00.0       267                PEK   980  1255
# 3    ALA       CP     00:00.0       875                DME   775  1070
# 4    ALA       CP     00:00.0       875                DME   775  1070
# 5    ALA       CP     00:00.0       875                DME   775  1070
# 6    ALA       CP     00:00.0       911                IST   715  1085
# 7    ALA       CP     00:00.0       937                FRA   430   710
# 8    ALA       CP     00:00.0       875                DME   775  1070
# 9    ALA       CP     00:00.0       875                DME   775  1070
# 10   ALA       FO     00:00.0       875                DME   775  1070
# 11   ALA       FO     00:00.0       267                PEK   980  1255
# 12   ALA       FO     00:00.0       135                LED   735  1060
# 13   ALA       FO     00:00.0       875                DME   775  1070
# 14   ALA       FO     00:00.0       267                PEK   980  1255
# 15   ALA       CP     00:00.0       875                DME   775  1070
# 16   ALA       CP     00:00.0       267                PEK   980  1255
# 17   ALA       CP     00:00.0       135                LED   735  1060
# 18   ALA       CP     00:00.0       875                DME   775  1070
# 19   ALA       CP     00:00.0       267                PEK   980  1255
# 20   ALA       CP     00:00.0       875                DME   775  1070
# 21   ALA       FO     00:00.0       135                LED   735  1060
# 22   ALA       FO     00:00.0       875                DME   775  1070
# 23   ALA       CP     00:00.0       135                LED   735  1060
# 24   ALA       CP     00:00.0       875                DME   775  1070
# 25   ALA       CP     00:00.0       267                PEK   980  1255
# 26   ALA       CP     00:00.0       267                PEK   980  1255
# 27   ALA       CP     00:00.0       135                LED   735  1060
# 28   ALA       CP     00:00.0       135                LED   735  1060
# 29   ALA       FO     00:00.0       875                DME   775  1070
# ..    ...      ...        ...       ...           ...   ...  ...   ...
# 275  ALA       FO     00:00.0       911                IST   715  1085
# 276  ALA       FO     00:00.0       911                IST   715  1085
# 277  ALA       FO     00:00.0       401                KBP   710  1025
# 278  ALA       CP     00:00.0       135                LED   735  1060
# 279  ALA       CP     00:00.0       401                KBP   710  1025
# 280  ALA       CP     00:00.0       405                KBP    55   390
# 281  ALA       CP     00:00.0       903                AMS   135   460
# 282  ALA       CP     00:00.0       153                LED   135   460
# 283  ALA       CP     00:00.0       903                AMS   135   460
# 284  ALA       CP     00:00.0       903                AMS   135   460
# 285  ALA       CP     00:00.0       903                AMS   135   460
# 286  ALA       CP     00:00.0       903                AMS   135   460
# 287  ALA       CP     00:00.0       405                KBP    55   390
# 288  ALA       FO     00:00.0       903                AMS   135   460
# 289  ALA       CP     00:00.0       947                FRA    20   330
# 290  ALA       CP     00:00.0       947                FRA    20   330
# 291  ALA       FO     00:00.0       947                FRA    20   330
# 292  ALA       CP     00:00.0       903                AMS   135   460
# 293  ALA       CP     00:00.0       947                FRA    20   330
# 294  ALA       FO     00:00.0       947                FRA    20   330
# 295  ALA       CP     00:00.0       947                FRA    20   330
# 296  ALA       FO     00:00.0       947                FRA    20   330
# 297  ALA       FO     00:00.0       903                AMS   135   460
# 298  ALA       FO     00:00.0       947                FRA    20   330
# 299  ALA       FO     00:00.0       947                FRA    20   330
# 300  ALA       FO     00:00.0       947                FRA    20   330
# 301  ALA       FO     00:00.0       903                AMS   135   460
# 302  ALA       FO     00:00.0       903                AMS   135   460
# 303  ALA       FO     00:00.0       405                KBP    55   390
# 304  ALA       CP     00:00.0       903                AMS   135   460
#
#     layovertime  arr_y
# 0         23:50    2.0
# 1         23:50    2.0
# 2         23:15    NaN
# 3         23:45    1.0
# 4         23:20    1.0
# 5         23:45    1.0
# 6         23:25    1.0
# 7         18:30    NaN
# 8         23:29    1.0
# 9         23:30    1.0
# 10        23:50    1.0
# 11        23:10    1.0
# 12        14:00    1.0
# 13        23:50    1.0
# 14        23:15    1.0
# 15        23:50    2.0
# 16        23:15    2.0
# 17        22:35    2.0
# 18        23:25    2.0
# 19        22:25    1.0
# 20        23:25    1.0
# 21        14:40    NaN
# 22        23:25    1.0
# 23        14:40    1.0
# 24        23:30    1.0
# 25        23,82    NaN
# 26        23:50    NaN
# 27        23,47    NaN
# 28        23:25    NaN
# 29        23:45    1.0
# ..          ...    ...
# 275    48:55:00    NaN
# 276    48:10:00    2.0
# 277    48:45:00    2.0
# 278    48:10:00    1.0
# 279    48:45:00    1.0
# 280    58:35:00    1.0
# 281    49:35:00    1.0
# 282    56:35:00    1.0
# 283    49:30:00    NaN
# 284    73:30:00    NaN
# 285       73,07    1.0
# 286    73:05:00    1.0
# 287    83:00:00    1.0
# 288    72:43:00    NaN
# 289    78:15:00    1.0
# 290    78:05:00    NaN
# 291    78:15:00    2.0
# 292    73:15:00    NaN
# 293    78:15:00    1.0
# 294    78:05:00    1.0
# 295    78:05:00    NaN
# 296    78:05:00    NaN
# 297    73:30:00    NaN
# 298       78,18    NaN
# 299    78:10:00    NaN
# 300    78:15:00    1.0
# 301    73:15:00    1.0
# 302    73:05:00    NaN
# 303    83:00:00    2.0
# 304    73:05:00    NaN
#
# [305 rows x 14 columns]

# %%
DME_FULL=ala.merge(res_dme, on ='aimsid', how='left')

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  arr_y
# 0       23:50    2.0
# 1       23:50    2.0
# 2       23:15    NaN
# 3       23:45    1.0
# 4       23:20    1.0

# %%
DME_FULL=DME_FULL.rename(columns={"arr_y":"DME"})

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME
# 0       23:50  2.0
# 1       23:50  2.0
# 2       23:15  NaN
# 3       23:45  1.0
# 4       23:20  1.0

# %%
##заменить нан на 0 
##convert float na int
#delete duplicates

ala.head(5)
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix   arr  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime
# 0       23:50
# 1       23:50
# 2       23:15
# 3       23:45
# 4       23:20

# %%
DME_FULL=DME_FULL.fillna(0)

# %%
DME_FULL.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME
# 0       23:50  2.0
# 1       23:50  2.0
# 2       23:15  0.0
# 3       23:45  1.0
# 4       23:20  1.0

# %%
DME_FULL=DME_FULL.astype({"DME":"int32"})

# %%
PEK=ala[ala['arr'].str.strip()=='PEK']

# %%
PEK=PEK.groupby('aimsid')['arr'].value_counts()

# %%
PEK=PEK.fillna(0)

# %%
PEK.head()
# Out:
# aimsid  arr
# 76      PEK     1
# 97      PEK     1
# 626     PEK     1
# 768     PEK     2
# 835     PEK     1
# Name: arr, dtype: int64

# %%
DME_PEK=DME_FULL.merge(PEK, on ='aimsid', how='left')

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  arr
# 0       23:50    2  NaN
# 1       23:50    2  NaN
# 2       23:15    0  1.0
# 3       23:45    1  NaN
# 4       23:20    1  1.0

# %%
DME_PEK.count()
# Out:
# nights           305
# aimsid           305
# name             305
# fleet            305
# base             305
# position         305
# flightdate       305
# flightno         305
# flightpostfix    305
# arr_x            305
# std              305
# sta              305
# layovertime      305
# DME              305
# arr              132
# dtype: int64

# %%
DME_PEK=DME_PEK.fillna(0)

# %%
DME_PEK= DME_PEK.astype({"arr":"int32"})

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  arr
# 0       23:50    2    0
# 1       23:50    2    0
# 2       23:15    0    1
# 3       23:45    1    0
# 4       23:20    1    1

# %%
DME_PEK=DME_PEK.rename(columns={"arr":"PEK"})

# %%
DME_PEK.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK
# 0       23:50    2    0
# 1       23:50    2    0
# 2       23:15    0    1
# 3       23:45    1    0
# 4       23:20    1    1

# %%
IST=ala[ala['arr'].str.strip()=='IST']

# %%
IST.head()
# Out:
#     nights  aimsid                                               name  fleet  \
# 6        0     661  NEKRASSOV ANATOLIY                            ...    320
# 39       0    5294  SHAIKEN MADIYAR                               ...    320
# 47       0    5738  BELYAYEV YEVGENIY                             ...    320
# 51       0    6533  SEBEKOV YERZHAN                               ...    320
# 64       0    7574  TURMATOV YERNUR                               ...    320
#
#     base position flightdate  flightno flightpostfix   arr  std   sta  \
# 6   ALA       CP     00:00.0       911                IST   715  1085
# 39  ALA       FO     00:00.0       911                IST   715  1085
# 47  ALA       CP     00:00.0       911                IST   715  1085
# 51  ALA       FO     00:00.0       911                IST   715  1085
# 64  ALA       FO     00:00.0       911                IST   715  1085
#
#    layovertime
# 6        23:25
# 39       22:55
# 47       22:30
# 51       23:20
# 64       23:25

# %%
IST=IST.groupby('aimsid')['arr'].value_counts()

# %%
IST.head()
# Out:
# aimsid  arr
# 229     IST     1
# 547     IST     1
# 661     IST     1
# 776     IST     1
# 781     IST     1
# Name: arr, dtype: int64

# %%
DME_PEK_IST=DME_PEK.merge(IST, on ='aimsid', how='left')

# %%
DME_PEK_IST=DME_PEK_IST.fillna(0)

# %%
DME_PEK_IST.head()
# Out:
#    nights  aimsid                                               name  fleet  \
# 0       0      41  ZHILISBAYEV MARAT                             ...    320
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
# 2       0      97  SATBALDIYEV ADIL                              ...    320
# 3       0     547  STULBO GENNADIY                               ...    320
# 4       0     626  BEKEYEV ZHANAIDAR                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 0  ALA       CP     00:00.0       875                DME   775  1070
# 1  ALA       CP     00:00.0       875                DME   775  1070
# 2  ALA       CP     00:00.0       267                PEK   980  1255
# 3  ALA       CP     00:00.0       875                DME   775  1070
# 4  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  arr
# 0       23:50    2    0  0.0
# 1       23:50    2    0  0.0
# 2       23:15    0    1  0.0
# 3       23:45    1    0  1.0
# 4       23:20    1    1  0.0

# %%
DME_PEK_IST=DME_PEK_IST.astype({"arr":"int32"})

# %%
DME_PEK_IST[DME_PEK_IST.duplicated()]
# Out:
#    nights  aimsid                                               name  fleet  \
# 1       0      41  ZHILISBAYEV MARAT                             ...    320
#
#    base position flightdate  flightno flightpostfix arr_x  std   sta  \
# 1  ALA       CP     00:00.0       875                DME   775  1070
#
#   layovertime  DME  PEK  arr
# 1       23:50    2    0    0

# %%
DME_PEK_IST=DME_PEK_IST.drop_duplicates()
